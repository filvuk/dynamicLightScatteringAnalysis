# %%
import main
from pathlib import Path

# %%
base = Path("/home/filip/OneDrive/Chemie/Veranstaltungen/Master/Forschungspraktika/robert/DLS precise/DLS precise")
main.plot_radius_distribution(base / "FV3")
#main.plot_radius_distribution(Path() / "FV_TEST", validation = True)
# Out:
# /home/filip/Projekte/dynamiclightscatteringanalysis/helpers.py:80: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt( (g2-1) / beta) # unitless
# Particle size at maximum is [207.9] nm
# Particle size at maximum is [225.5] nm
# Particle size at maximum is [225.5] nm
# Particle size at maximum is [1.000000e-01 2.710000e+01 2.655000e+02 7.217333e+05] nm
# Particle size at maximum is [1.000e-01 4.900e+00 2.255e+02] nm
# Particle size at maximum is [4.790000e+01 2.880000e+02 3.759501e+05] nm
# Particle size at maximum is [1.916000e+02 6.131477e+05] nm
# Particle size at maximum is [1.000e-01 2.255e+02] nm
# Particle size at maximum is [1.916000e+02 7.830375e+05] nm
# Particle size at maximum is [1.000000e-01 1.916000e+02 7.217333e+05] nm
# Particle size at maximum is [ 29.4 225.5] nm
# Particle size at maximum is [1.000000e-01 2.079000e+02 7.217333e+05] nm
# Particle size at maximum is [1.916000e+02 6.652286e+05] nm
# ...
